# %% [markdown]
# # 012.图像的加法运算

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img01 = cv2.imread("./data/1_BF.jpg",cv2.IMREAD_ANYCOLOR)
img02 = cv2.imread("./data/1_DAPI.jpg",cv2.IMREAD_ANYCOLOR)

img_addcv = cv2.add(img01,img02)
img_addnp = img01 + img02

plt.subplot(221),plt.title("1. addCV"),plt.axis("off")
plt.imshow(cv2.cvtColor(img_addcv,cv2.COLOR_BGR2RGB))

plt.subplot(222),plt.title("2. addNP"),plt.axis("off")
plt.imshow(cv2.cvtColor(img_addnp,cv2.COLOR_BGR2RGB))

cv2.imwrite("./dataplt/addCV.png",img_addcv)
cv2.imwrite("./dataplt/addNP.png",img_addnp)
# Out:
# True
